# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_csv("datasets/train.csv") #filepath
#data = pd.read_csv("datasets/training.csv") #filepat
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train = pd.read_csv("datasets/training.csv") #filepath
train_cut = train.drop(train[train.min_ANNmuon <= 0.4].index)
x = train_cut.drop(['min_ANNmuon', 'mass', 'production', 'signal', 'id', 'SPDhits'], axis = 1)
y = train_cut['signal']
#x = x.reshape(-1,1)
pd.set_option('display.max_columns', None)
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state = 0)
model = RandomForestRegressor(random_state=0)
model.fit(train_x, train_y)
preds_val = model.predict(val_x)
val_mae = mean_absolute_error(val_y, preds_val)
print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))

rf_model = RandomForestRegressor(random_state=1)
rf_model.fit(train_x, train_y)
rf_val_predictions = rf_model.predict(val_x)
rf_val_mae = mean_absolute_error(rf_val_predictions, val_y)
print("Validation MAE for Random Forest Model: {:,.0f}".format(rf_val_mae))
# Out:
# Validation MAE for best value of max_leaf_nodes: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [24], line 15
#      12 print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))
#      14 rf_model = RandomForestRegressor(random_state=1)
# ---> 15 rf_model.fit(train_x, train_y)
#      16 rf_val_predictions = rf_model.predict(val_x)
#      17 rf_val_mae = mean_absolute_error(rf_val_predictions, val_y)
#
# File ~/Storage/Software/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:474, in BaseForest.fit(self, X, y, sample_weight)
#     463 trees = [
#     464     self._make_estimator(append=False, random_state=random_state)
#     465     for i in range(n_more_estimators)
#     466 ]
#     468 # Parallel loop: we prefer the threading backend as the Cython code
# ...

# %% [markdown]
# # Predicción

# %%
test = pd.read_csv("datasets/test.csv") #filepath
#data = pd.read_csv("datasets/training.csv") #filepat
test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
# The list of columns is stored in a variable called features
test_x = train_cut.drop(['min_ANNmuon', 'mass', 'production', 'signal', 'id', 'SPDhits'], axis = 1)
# make predictions which we will submit. 
test_preds = rf_model.predict(test_x)

# The lines below shows how to save predictions in format used for competition scoring
# Just uncomment them.

output = pd.DataFrame({'Id': test.Id,
                       'SalePrice': test_preds})
output.to_csv('submission.csv', index=False)
